# %% [markdown]
# ## Mini-Decoder Architecture

# %%
# to read doc files install python-docx library
pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 7.5 MB/s eta 0:00:00m eta 0:00:01m:010:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=2.3.2 in /home/nikhil/miniconda3/envs/projects/lib/python3.11/site-packages (from python-docx) (4.9.2)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184490 sha256=a838ec79b4b03454471d36201473aa38bd7286f8135bb622bbb5654f633e2c4d
#   Stored in directory: /home/nikhil/.cache/pip/wheels/b2/11/b8/209e41af524253c9ba6c2a8b8ecec0f98ecbc28c732512803c
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# import docx from the python-docx library
import docx

# %%
# this pip install for only TPU not for GPU .....Recommended is GPU as TPU in general are only for very large processing i.e a very large batch size.
#!pip install cloud-tpu-client==0.10 torch==2.0.1 torchvision https://storage.googleapis.com/tpu-pytorch/wheels/cuda/117/torch_xla-2.0-cp310-cp310-linux_x86_64.whl --force-reinstall

# %%
# import pytorch library
import torch

# the below import is needed if you are using a xla device i.e if you are running this on a TPU
#import torch_xla.core.xla_model as xm

# import the nn module from the torch.nn package of the pytorch library
import torch.nn as nn

# import the functional modle from torch.nn package. This module provides a collection of useful functions that are commonly used in Neural network operations.
from torch.nn import functional as F


#Set the hyperparameters
batch_size = 64 
block_size = 256 
max_iters = 5000
eval_interval = 100
learning_rate = 1e-4
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Again the device should be set as given below if you are using a TPU device
#device = xm.xla_device()

eval_iters = 200
n_embd = 512
n_head = 8
n_layer = 8
dropout = 0.1

# We seed the environment to get the same output
torch.manual_seed(108)

# Load the document on which we want to train our model
doc = docx.Document('/content/Mahabharat annotated .docx')

text = ''
for paragraph in doc.paragraphs:
    text += paragraph.text + '\n'


# All the unique characters that occur in this text from the document. 
chars = sorted(list(set(text)))
vocab_size = len(chars) # we have a total of 82 characters which we can check by printing the vocab_size


# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }

# takes a string input and outputs a list of integer 
encode = lambda s: [stoi[c] for c in s] 
# takes a list of integer  and outputs a string
decode = lambda l: ''.join([itos[i] for i in l])
 
# Encoding the entire text dataset and then split it into Train and Validation sets. First 90% will be the train set, and rest  will be validation dataset
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) 
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# Create a function to compute the average loss of the model on the training and validation sets
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=10000)[0].tolist()))
# Out:
# 25.42293 M parameters
# step 0: train loss 4.5513, val loss 4.5508
# step 100: train loss 2.4510, val loss 2.4608
# step 200: train loss 2.4015, val loss 2.4034
# step 300: train loss 2.3747, val loss 2.3758
# step 400: train loss 2.3447, val loss 2.3498
# step 500: train loss 2.2940, val loss 2.2985
# step 600: train loss 2.1488, val loss 2.1569
# step 700: train loss 1.9789, val loss 1.9863
# step 800: train loss 1.8717, val loss 1.8817
# step 900: train loss 1.7846, val loss 1.7976
# step 1000: train loss 1.7172, val loss 1.7268
# step 1100: train loss 1.6491, val loss 1.6595
# step 1200: train loss 1.5933, val loss 1.5968
# step 1300: train loss 1.5399, val loss 1.5531
# step 1400: train loss 1.5001, val loss 1.5120
# step 1500: train loss 1.4577, val loss 1.4702
# step 1600: train loss 1.4273, val loss 1.4385
# step 1700: train loss 1.3959, val loss 1.4059
# step 1800: train loss 1.3749, val loss 1.3844
# step 1900: train loss 1.3466, val loss 1.3561
# step 2000: train loss 1.3260, val loss 1.3377
# step 2100: train loss 1.3086, val loss 1.3227
# step 2200: train loss 1.2859, val loss 1.2992
# step 2300: train loss 1.2759, val loss 1.2874
# step 2400: train loss 1.2569, val loss 1.2691
# step 2500: train loss 1.2455, val loss 1.2554
# step 2600: train loss 1.2328, val loss 1.2474
# step 2700: train loss 1.2200, val loss 1.2323
# step 2800: train loss 1.2085, val loss 1.2255
# step 2900: train loss 1.1970, val loss 1.2143
# step 3000: train loss 1.1893, val loss 1.2036
# step 3100: train loss 1.1789, val loss 1.1946
# step 3200: train loss 1.1688, val loss 1.1857
# step 3300: train loss 1.1633, val loss 1.1804
# step 3400: train loss 1.1583, val loss 1.1768
# step 3500: train loss 1.1495, val loss 1.1659
# step 3600: train loss 1.1459, val loss 1.1620
# step 3700: train loss 1.1360, val loss 1.1547
# step 3800: train loss 1.1265, val loss 1.1484
# step 3900: train loss 1.1256, val loss 1.1429
# step 4000: train loss 1.1163, val loss 1.1337
# step 4100: train loss 1.1130, val loss 1.1329
# step 4200: train loss 1.1056, val loss 1.1267
# step 4300: train loss 1.1027, val loss 1.1214
# step 4400: train loss 1.0967, val loss 1.1175
# step 4500: train loss 1.0927, val loss 1.1166
# step 4600: train loss 1.0879, val loss 1.1083
# step 4700: train loss 1.0803, val loss 1.0997
# step 4800: train loss 1.0785, val loss 1.1013
# step 4900: train loss 1.0732, val loss 1.0943
# step 4999: train loss 1.0669, val loss 1.0906
#
# "
#
# "Sanjaya, rushed acts the Markasra taking the mace of the subsistenance of vows, he thunder of the Rishis, began to comt the preceptor of foes, like a rality of terrible the kings and celestial, which is called in place, attend at those that risher by very powerful hostinedly and difficulty comingly, O bull of Bhasta's race, proceeded to living grief, caping into striking (his bog. Beholding) these weilder (out), other has stated one should becomes and seeized firsh goats. And vokey avoiding me who was birds. Then Karna and never happenetrable of a long whose highly sons. A thou tent reservene the sight of virtue panic, are persons of wrath pide and is done. Syoungh pass her desireded, his fired for her battle, in speeding to here. Sesides O ruler of learned the body armour of at I will should be desired. A forgiving away from bulls of speeches. Even thus comprehends as so Could over on the breest. Desires by the birth of the soul earth, he dam disaghter themself. And those discourse of lamentapous that slayer of acts, never success, and his virtued with the valiant sufferiors, tiger and wielder of sacrifices. The making his pleople, as if those had hath been became brought, Like leads placing trooops and regard and watere and great his desired. Go, O king. Marifying, the forgiventeenth of goit boons and ten comforty he too. He is eighter this virtue to conds it byd. Then Ganga, offereted all creation. Thou that that frought disamplish from what rabined thou, it behoveth me as that I son shall be that wicked subjusece. For faultless, Vena. thou wast supported in the highest which the season thou shouldst the field of speech sweet me. Hence as not thee to be, thou livest very pligh as composes thyself.' As assailed, "I know not is possessed of seems with
#
# broath, the son of Vripa such rememering the conlifience of the (when, if frestrent as with seek me. By the dist, the its world, with never cold the weapons (that we intelligence men, himself be it. O bull among myself gods, whethou, having intelled. O lord of the son of Kuru thou hast become hime.'
#
# 'Health with the mind of repeteat rouble covete by their many adorable this skies in the called Prads, saying, 'And Brigu'son. The Gods and Yamodi self I wish thee, O Bharata, the also those peoples that Then fenither grastist in posperity of all's relity according to the mighty Panchalas. Nuch a prigent of his bown a perfice of hostodern upon which is superied as Indra high sweet inceptreth the either with arrows. And post off at Vidyura.[2638] Alas had pod, one some the arrow restrain, apply a ye own ground. I tell me that king, Rukshasa then slay of under thou she should I had come in thy toop. By that Sindhu should give for it. I hath no father's sport in grief-ried, having the woe.' Then the ask Beholding himself, is celebrated on these. I know throw. Rangindful is prowess in the waters enducing thy alleaders and the skin, stucks not as he cased also to in the decept. The gems also for which eyes accomplis performed a orders from up. When the sacre? The man assemble in created that is penetrating wone. That thus is the ouring is a occapity away, makeya fury of the great bast, indeed in the days of acquing speak of great forest. Do not opprect observed from in birth. I all have to be place pierced with giving lightness. And every known towns, accreptainely a meven continued, the sheadness loze, that forest of del objections of citer. There breating king Vritra, for he plungess and have (to cast thou the ground of the gods and) perfect, and beheld these words, O best of gold, as slaying in confident's drighteneness in hefulgence to the choick. Thou art he sin. Without art can incontry conclouds. Thou illustrest thou shalt insterve the daughter of the Vedas! I am great my father, everything, whatever, king Surya. Singly with Janamejha, Karna agaid as excellent brother, and they failes, in this weapons, it loves, retrains is Abhimanyu weapons. And, O Bharata, taking up of Varnashtra, thus caused thy king. Now it was first. And the wheel-gefter of Bhrigu these two stay in excellent bow untothers and consted wheels, 'O terrible with me shall become do not give when away requished this that showered him is born by Ratha terrors are citied with great breathing of great. And resembled the attribute of thy words, Bhishma know particulary hundred. And Drona, humbbled, filled with where large randsing. As reside there in water to enhreport in Truth. And saying, 'O bull of the Vrishnis anx well come in whose renully dothers is revidenerly the path of one decar and also. And these words from his prities. Then, O king, this the, thus wert tasted with the hands. And as, errded not the Pancharityyas were crushed away the exterminate of preparatication Sriti. O Uantividual kings, the share through the pleasanes of great ascetic. And Garhasva, (bearing to me). Upon the princes."
#
# Exterminatora continued, Hearing Saidum these words unto the same spake of righteousness person as their eaddy like a thyself mountain and not thende. And some to duty always and vantryas and peneted a most call to be a hundred froming vigilanc upward eyes on seek thy power. And when Bhishma southing exceptor diverse specked with eaging them as erterealy external comfort. In those held deserveth and the (prowess of small) car at their form and a pain of all burning grories energy. The king coveted them in thstat energy with never bows and wisdom, entered the great Rishi and wepelled or that obtain bow, and the exmingl standing of all the the urged compar. And he highly and perfulged in his way, Turnt unto he; and like a all boon, he are everty like the could combey to thy became respect. Exceedingly (indiffers) engage energy before unto the Siddhas equal regard, and wealth of his virtue, O whollow the son of Pandu who has to wicked everywhelmoo. The wold consistion of their troops ergoner, when the wielder, sancts with greatless then created authlesse by foes, where Falguni! Torak the sease of lightning viquished by aimuse not down prowess as to the Srings: and had together and proper continuated. Their custs and a keeping with every breakety, or the gratification, or decepial over heads that sought himnellors and grief the Apsaras and kaningdomen and worlds the cames of the shaft, the past rosal of his life. And it islain., a perform a Brahmana practised with sweon the very kind. It is were well-bestaked for kine mild on.' Lamasent, there Mita arksha and Samadhanika, the deitiled of birth and the of Dwhola brought in the fields, bhe her, risen in who always wishes undered it. Dakshas plage the walk, suchends, seeing on the merit of my brishmany prostrated him from sinful trustrenesse. One that time hath nose and swords and grasudes and fourth of Bhagirata. Thou art learn. Holly there from one is true every words. Thus stilll in his that seyeth on being sharp-excients that what (which) is consequence it., Other bull amongst men, therefore, everything it subject of terrive. O owifer, to of Vrishni; it is becomes foremost of perception. I think the name of Draupadyumna behood, even thome to lake through offinients. From the is day beneficiate of this pleasure. While while thou is greatly did, thou art evil the openth and is fire. There is no car we seent to a gift him whose halp been differenced in immensions. On of thine that struck pricess. They who was repeatedly that sat loud of possessions. Thy that hero was fagral after the rejoys to down Hearing so. There is excited with three in scorch of morality, hatoched befamed upon from the regions, sometimately by the deities the forficient strength. Possessed by the newthers of the cardief, the desiring of choise and ignapably, and by the very son of the Kunti is dopposing thy time awfully, cout humility to go the Brahman made of the mighty car-warrior intermies. He, or inseaments of the soul, while emern these and good best of lebroud in antrightening and kinds, glea-pealeth upon the Kshatriyas towards the fiffice the Apsishthiras, desire to away. The man, he Kogsalas, he was the driver of his body, even on her slave lord. As the words of heads there also together with the sun endueth to bear the universe, what the Pandavas will say on hear. Firm have heard this making diverse as deserve cha been firmly may fught away. I think to thee that not phowers take themselves had apperty a forbidant you observest, O monarch, who never burnt from cooks where everything, by a Brahmana lad, when are them are liquips towards like a blazing those flesh which, giver was fleet. And every compared, of this battle like unto Krishnara train and by falling toe proper? Those sons warrior of spires Bharata, has completed that of all creatures, the ocean with ear. Arth Bhrigu then indications that share words her after his dry, and proceeding to the death with every judge river weapons. Always so treme ...

# %%
print(decode(m.generate(context, max_new_tokens=20000)[0].tolist()))
# Out:
# said Tama also in the Sretas that free as unan(for I fallen) of them' sons again with the of aim of hostile. Then Aditya, the Vedana began to see hat Bhima which was penetrated to desire in scatter of his own incapable of regain. We called as the mighty Daupas. Like the Rivershis of Kunti went destroyemed to be ergone. Behold, O lord, I desire the birds. One king, the Istoried reasoly to the sender of Kasyapa! When the elephant, took Emancipation in the reyes is devoted to that should persons and attires and trusble. O Brahmana, there we will what over here? Those behelds having to sill. The world preceptor's rage, like the prowess up the permit of other arrows capable of poortion in his life. Where king doth is hither even nights while them went upon the mouth.'
#
# "And mindful hearing dlished the words (worshipping the mantras), engaged with an ewhere speedily derivied, it is all me. The all, O Hersh, Uparavas the great body will rushed Cheding the resemble by the gods.'
#
# "King do now the thus all, the sound Rishis, Dhrishtadyumna, I grow2] Thung skilled with a mighty-armed spoke, still into him ingresse of wealth. And you are, with others and troyal and robbedied to art decked with a gods, they share. What showeth pride, thou wilt the receive innumber, therefore, O bull one's righteous warriors. And the Partha bestowed of me,0 of sleepering me and brought by various, to such well sorrows upon the vigour of his performance possessing alone gladdeneth in mulity, O thou of Bhimasena's race, O Bharata, to retreat my, the Kuru is a son spot for driven with their blisteness for mightier, which the Palgunar the ocean another of the Madri chase of Agnihour. As king, Drona's army and accompanied by Keshavi famelessly, was perpetrated my haest for deserful to himself. That foremost alone warriors by the Parthas as also, the Kurus, and this, of our personal of earth, fashing the high sties) in these words with thee. And beholding with seven dilifereth the heighest. That Drupada, Bhishma she words then shad, 'O king of his ascend the two ascetic cars rise, and replied, Duhshka and Garuda's sone and soot the king's then son of the glory the Matsya, indicate ever by his been seatined. Of cogs was made power of what strange, and is to consol death of one's equal with his performar and great eight and of her, viz., three-eye, thou then, tell-and Kridhaswa. The (sway) arrows, he eldephants and prosperity, saying, 'Would repeatedly ones conquent. Behold the worlds of men excited with that relative Bhima (the Darupadi) of the earth driver destruction of the court stingless of the close and against into conclours competen it urthful's deeds. By meat why intercount. A whom appraorateth, from pervading of gifts of sacrifices and those fear of observants. He did not fierce entury limbs, Madels, I see with a huge it. O men of my day, a Pitry, pay his hands live before them essengres steeds unto whim a Brahmana wrior Indra; thou shalt thyse royal happiness us inclusing in rahmanas. O exiding proceed a nanger risers, cavering like the sense begotten in princers that one that then. Thyself all the just, extensive, began to be thine.[1275] Ever river, O monarch! The two mornister the time, ran the dismicar to Mantri; and by the meror nothing Sudrasena sake must the felicity of the Ccouplexion. Call of copper any hath touched me. The other head, those kings (This deful observance) that last of innumersue hundreds and blowing lightess of concounwards and southuted by observances and put me. He is laughtering the house of all, youther worship in still gift on his own which I reright of his consequence of pourer of good intelligent counse.' Then may words I have do what, who related him like health, ever unto the dissingle, who is the world to be even lightned (on the same) for the prepared bodies. Let he not behold his careerers practice to him every of Gay, hath his adoptic! Beholding him with weapons in! The best dight of a creature and wrach hedd the sake and sons? Everything after the passeth the sacrifice Vasudeva and the husband, addressed him, success, the Sun's inverse the man, even became ye prope if a boon the highly ascetic for a wipe prowess. O son of Bharata, the Pandava appertanally she many self-restraining the senses one amongsters. O bulll of the Supreme unto the Yairasu, seeinly all, and procurs and seemed for a kningledge with it. Some to the king of them ever as the puissance of all the monalings. Proceeding at the celestials set one's great, when, mouse explain everyth do, without doubt, the exirtion of joy. Then, O husband, if the hands! There with his permission mode and various splented, and encounter contentments all the son purposest compligent. At king! Going kings in all those bloods, the kings of the twin them battle, and meds of a ladifies. That is the bow of a kingdom. The Groga ride the knowled of oblatiation, is the Kurus shall, is the subject of all, blazing these wealth? Seeigh the Ranksha ...
#
# "Vaiswamitra said, 'When Set in thy mieting on the whole say it with fallen creatures and banner-ranging juin-proper on dearly waited with weapons. That ruler of danguiding, in power (in what touch she owinged by them. Subjuga' conducted their life waiting the supresent shafts some of kings' restrained, shouldstly of bows decerts adopting the mighty Narayana saw, as she cast on bend!' Indeed, said, "Yudhishthira he sparkets of his desires. The mighty bousing straights sons of Chitraraswation and youth heroes. Even all ovice, pierced with thou shout ascetic now gond. Welancour, both in whose others act (for onestroy him) and charious cheless, drivers, arrived with the eldest of obtain life? He caused him by the found of evil acts of which were so those hands). And that seemed by many sin. The son of Bharata make his bow, none self-rushet with rights and happen. One should all weapons, forsembled by the righteous bow-strilegants the way in restrained by equal with great energy, encountering one thee. These equaral is ominion in the requests was. Within has held and dear in the moments of Yudhishthis the righteous should regions from its abode by those counsions of accomples, excited with eyes and Brahmana and Brahman, exceedingly agingated me, Critaror, fathing in huntous and thy troops and stars and bows that thou hast covered with thy rescuing at thy bring down the erst. Krishna in both of thy company, rinders to my bow lequal rounch. The Bharata with shrield like that descriptior) of you shall be slaining with jadgment. Like the cert of Drupada that is sactified by lessons of drave possessed of their flames!
#
# "The Kuru army was both her down on achief all the earth.' Seeing these words of the penance. Whatever are the meritorious and fell tirthas, ye have gained, O Sinjaya!' Hearing this weapons of food, this, O hero, say thy atttention, therefore, now rays obtainast of a villagrous being regardeded by Yokshishipa, for Drona himself, and the espaciance of all worshipful in days had to become for bodies, does, never thus ahen and in case other stay!' And the beginness the burns of the Earth, Satyaki of metus elephants, won, sooft, and desired the peropection of ascend order with the earth. The gate, the day scar touch, while he come sacrifice the foes. I will hath excellesting the year of ascended a wondy. The numerous quickly had to old by all weapons. I draw, Salyabha lever both of the cheerful and part by dows. They would to sons of them in the region of with good at thy sons of whose king you, who is invappished from attacles creatures, it at the woods, therefore, the mon say not grass. The son of Mithini, the pierced Yuga,' head been it spring from equal here by the Brahmanas. He saying, Sala the kingdom of those displaying the royal Prastika and Turposala Ratha. Ne, utter last livel unto takes of a causion him in the high-soules of the foe, causing always and be brothers. He was addressed Kunti and known the huer poince, Arjuna and Sustaki and the Brahmanas excited with weapons and disful. He cast off the sage of the Welfare, the abode of worthy cannot, Dhritarashna should be performed by grasp as shooting purpose. Then placing elephants always the abodiment of all the fields possess of beggot with every head before them, ye should be the nuwuly and obtainess created mander. Thy warriors had to excepted alighted with javele whom ears. By desirous of lake the voice, with goad and arrow. Those the slaky shines, in that host body equal and giving Bhowship in Dost
#
# able of position and what careful in high pacefull. The beautiful intelligence (to Him) when engaged it as their souts or by the rothers sons of Parityu on his own when to become variety, said,--'Well-appear, O son, the hero son of the Kurus. O grond, that gods having endued with, having proceeding Yudhishthira was became this senses. Who makey recit by husbands of robes the scalfing Yughishthira the preceptor's (skin) deserve, destitute on mind of tire, clad baffle, having flowerled with the consulty seed on husband cheerless, and bones to the mind of thics energy deeply, and the twin to puissant him, they set became (that sacry) him in these terrible day cows. The men of devotion everywhere perficing as the teeling his kings speed more break Vishnu called bequefieth the liver in the veryts. Grounds, desiring having virk Indra to the palm unto the king. Extraory retreat away his brossings and steeds, therefings, as sking offend by law; they beheld thy carnage fearlessly equipped with the royal begret with one parts and equipped by the Fame, gave on the slay, out east, do this wobjer that grandson who was to disciple. And a huge king of those (with) wishes hard fire from everything where swort by contracting, the chief will born by what was always sured with those deity procuring. And those excellent steed and wife was also of his bashes and wondered away. What practise in seake. For those for men upon grativing away, a day, article than of the Brahmanas between him. On
#
#
# Bhimasena in the duty, O Bhaga, causing the deities, that arriye worship have been to odays or the company in the serperhing! When that has bell repeatedly a desistible point in leaveing by His hauntiverse words. If he that had he beened sacrificed and his sect one and beings! From the mobjes till action experity to disay al' one and bliss of virtue at Se-had O lord. After everything the best of knone behave the left. And the twin religion of spare, and he plyressed the Sanks exertion of conduct. He battle, and winning, the seen of presented him great the Kurus rain on a Brahman and end himself strength and observant his days, and the presents, and afflaint he (and by pride). Karna great with sacrifices without her and kepensity the illustrious tripical desirable bleres innumered the learned she due in every he who decleased Si."
#
# SECTION LIII
#
# Vaipaudeva said, "Indeed, then, knew by What, O Duryodhana, plaughtere foes with both nisted injuge and profit of the whole objects. In what the Suta's son of the earth whetter is he is Citrana.'"
#
# SECTION XVI
#
# "Hearing many wifal unto one that abound with irresible at these the gods. O bull thou canting interrofal and be incovered by me. What be what what I know are got and the grant and complexion. Griet shill, that bulls thou shall ever constly, Opinerce one, forwarth, when now blossed by the means of my advancing Ashtavathama, Thas are very rend roars of gold closse, immovable proceeds, the king to Dusasana have (been by the rays of the bodies), and other, with sharp be combated and righteousness of arrows. Armed with strength and effects in retror fire in the track race. And these excellent cannot fear from his enembled its wrongs and children sended thou shouts me he influence with even he hard. Those deity to be, heard these weapons do now, in one limps of husbulilary. The mighty bestowing those thus kingdom from onten the fiery delight of his deer-imper disragrection. Do thou a tattribute to doing addressed with weapons forsament so behold and swalled by the man-bodies and monkey and homage, of her snake, (ex-remeply) dog. The all about of duni, let thy slaughter me. Give, have cut off hard bour performing savat, tell me!'
#
# Spast his were said, 'When there feat from his, the protection and others or life, they fight were prevened by Brahmanas point. By ever preceptors showers on the could particus of
# both the Kurus, and all the firest Brahmanas and instrumentaments, comming truly towards with him battle. Their severerous is waited with people, he survereneth with their should be modes devoted to blare fer achieved from thee, the earth of human being bathmany hurled the Danavvishindhabha regenerate conculage. wealth as his sought from from modiful ascendes and begotten a son as long pass even go through a many great men. Everything with equal ladieneth this many medicine so felt the blazing grasd him fall usuncquired prosperity of by righteous body. Duhshevasana these words of Yamuni, opeten, the hiest in maiden of the Yaughira's race. Then king Yuyudhana with his defection. And represed thus to laid down from it? O chief of those art those ministers of the three where years does not sorrow. Men that is equal the preceptor of the cruel, there is breath in me? Gratified with the leading and dry seet in lightning Rishyas and set it, O bested among men, in thus, O purposess of lyine supportion of in battle. Alas, having fear (on his sense worshing that situation the fierce's bowmen, must complexion, fraith of rush in dantival wood. Those two, the soul be pullable today encounter the aid of the Vedas. And hou werds from whiteful lead to The Nivata-givi! The Yavana surrounded my wings. Indeed, he elephant like the ten restrained in the lord of the three. And the Pandavas, the giver of his, verytous with Asuras. Duryodhana, cleabled overr Devote by me in the same of Kagaswa. And the gods warriors rays devoid to the daughter the god gave holdess. Let his beheld it was about by the Samade manantards of whence rejoyes to be scirch to be means. After kepth that is productifor, even the words. Any kings, it, king Duryodhana, he was a piercing could of bright race to them as insulte ascaing refugent desire, O Madhya, the high-souled sons? And the sense of his sons of moties being limb perpetial with desiry, allong the Pandavas. He took unto Trigardhas) with his That king Yama. And, O king, the king with the gods the sons Pandu. The mound, king who righteousness thy fame seped with might paid the pride into the barls. That full away to him, the distresses of excellent, for contrused the great was the burt of his eyes, and hears that was bathed fallen by Duryodhana. Vedura do on the pride of that would worly, full I heaven, with the Four many intentions, and after I rappeal unto slay Arjuna, and he red dangers adorned with gold. There are now to the Hikesa and warriors ble, nor with duty of the Shadevas, endepent, disming not grief, struck the suddens of the aunteration Brahmana a like ornapplace, to the celestialy swifarly in the great Rishi as eye. There is that thou worsh to belongeth history and rosped, adviciously break in (course), both is called Sivin, and the king Sun. This is. Resorting in the wife of dishevelled the Mritha could the people activing the godes bow indications to became his innumerable. Human beholding the lightness of Arjuna's course the day), the king preference, the thunderbolt woe both and left and wrath and prour to Maduka Nakula then. Havy then to that delight and Kegada, that I had, reforehed these Suta, became away. The foes, if this car, unto him for batth and drevice, consons himself behetweet the foe of the Kankayas he divine Partha knowledge. 'Ye, one deities, his bow, I appeace to ranks of all vanquished exerty, Arjuna amongst that he
#
# sake pleg to him. Therefore, O monarch, I am seemed to che the prieste. O Gondu, the most to be foremost of more depend-of such as a taking its every mornipor is body. The het host plough pure apprehend) Dharta, it fell down in this pointment called by the plesse (and insextications). Herely broad-man interest by Vakari then practices (that constand) the request, also, becomes as them. When that I desirous is not from appoint intextendic the Soul copple, it is performing the Sindhas. Therefore, O Durasa's army, as the just for my insinglence upon the three and taking through the energy. There is no only weapons of that, properly, thus wife, and year of the eternal difficulty. There is not behoveth creper of herself, to say the himself is in battle! The truth heroes rendered from the other battle I amoved, the kings of the Brahmana. There animatal beings and bewings, and workiness in who attain's thus carefully together in complete!'"
#
# "Bhishma said, 'Fig Pritha, Yudhi. Self-cheerebrs, they one should be apperfacorded all that prosperity and the foe, and made in the celestial and vials, and the king of the Pandavas, seizeth sire his, virtuous kine procepations and matchs (agained to hawle). Therefore, Sanjaya, Vedicate it.
#
#
# "The just, O Bharata, regardeter like the must of the Kshatriya (in installed) it. The war, O lord of whose Brahmanas, burnt the aadopt By and the large, bequent to great every will be ask town.
#
# 'Hearing that one, and whose two, the ruler of thine knowledge of clours with those words, I do not existence. Thereve were slay thou heepless (in the matter) before, finger do with his glory. The son Naraya assolute, and fever of stoil rules of merriations. Men of those is infurious whose the monarching ornaments (replied deeds) in the sconch lord, O Bhishma, then should and become said unto him, said, 'O hero, the monarchs--Wamalivous of power, that busineth it. Same them supty. Having swooness intented the souther; king by Dhrishtadyumna long splenge in ragge. Those lady bow meditation, to the monarch and skin himself, have been recounted by a sight shades of every foeathly down to his relies and leading living the mender for protection its sweet to spake. A Brahman, ye was lostoing live and desirous of them to god pour.'
#
# "Sanjayinga said, 'None are possessed of good beings, saying, one wall are diverse' seems, appuranity for desisting of soul and made (illusion) it was roble. And obtaining a Bhishma there showered in glap33]
#
#
# Sakra could also with the depent shafts and as it say everything of righteous Yogi's next wi
